# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np

# %% [markdown]
# ## Normal Distribuition
# A normal distribuition ta

# %%
x=np.random.normal(size=(2,3))

print(x)
# Out:
# [[-0.38471124 -0.17394661 -1.54563155]
#  [-0.83551242  1.18923447 -0.06777284]]
